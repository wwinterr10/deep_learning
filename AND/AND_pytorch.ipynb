# %%
import torch
import torch.optim as optim
import numpy as np

# %%
#AND 연산의 x1, x2를 저장하는 배열
X = torch.FloatTensor([
        [0, 0],
        [0, 1],
        [1, 0],
        [1, 1]
    ])

# %%
#AND 연산의 y출력을 저장하는 배열
y = torch.FloatTensor([
        [0],
        [0],
        [0],
        [1]
    ])

# %%
X
# Out:
# tensor([[0., 0.],
#         [0., 1.],
#         [1., 0.],
#         [1., 1.]])

# %%
y
# Out:
# tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])

# %%
#w에 곱해지는 값을 1, 2로 초기화
#학습을 통해 값이 변경되는 변수임을 명시(requires_grad = True)
w = torch.tensor([[1.0], [2.0]], requires_grad = True)

# %%
w
# Out:
# tensor([[1.],
#         [2.]], requires_grad=True)

# %%
#b에 더해지는 값을 3으로 초기화
#학습을 통해 값이 변경되는 변수임을 명시(requires_grad = True)
b = torch.tensor([3.0], requires_grad = True)

# %%
b
# Out:
# tensor([3.], requires_grad=True)

# %%
#배열 X와 w를 곱하고 b를 더함
torch.matmul(X, w) + b
# Out:
# tensor([[3.],
#         [5.],
#         [4.],
#         [6.]], grad_fn=<AddBackward0>)

# %%
#배열 X와 w를 곱한 뒤 b를 더한 값의 sigmoid 계산
torch.sigmoid(torch.matmul(X, w) + b)
# Out:
# tensor([[0.9526],
#         [0.9933],
#         [0.9820],
#         [0.9975]], grad_fn=<SigmoidBackward0>)

# %%
#optim.Adam([w, b] : 미분을 자동 계산하여 w, b를 수정할 객체 생성
# lr = 0.01 : learning_rate를 0.01로 설정
optimizer = optim.Adam([w, b], lr = 0.01)
optimizer
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 0
# )

# %%
#5000번 반복하여 오차가 0으로 수렴하는 w, b를 찾음
for i in range(5000):
    print("i=", i)
    print("w=", w)
    print("b=", b)

    #예측값을 hypothesis에 대입
    hypothesis = torch.sigmoid(torch.matmul(X, w) + b)
    print("hypothesis=", hypothesis)

    #오차를 계산해서 cost에 저장
    cost = torch.mean(-y * torch.log(hypothesis) - (1 - y) * torch.log(1 - hypothesis))
    print("cost=", cost)

    #cost를 이용하여 미분을 계산하고 w, b 업데이트
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    print("=" * 100)
# Out:
# i= 0
# w= tensor([[1.],
#         [2.]], requires_grad=True)
# b= tensor([3.], requires_grad=True)
# hypothesis= tensor([[0.9526],
#         [0.9933],
#         [0.9820],
#         [0.9975]], grad_fn=<SigmoidBackward0>)
# cost= tensor(3.0190, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 1
# w= tensor([[0.9900],
#         [1.9900]], requires_grad=True)
# b= tensor([2.9900], requires_grad=True)
# hypothesis= tensor([[0.9521],
#         [0.9932],
#         [0.9817],
#         [0.9975]], grad_fn=<SigmoidBackward0>)
# cost= tensor(3.0067, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 2
# w= tensor([[0.9800],
#         [1.9800]], requires_grad=True)
# b= tensor([2.9800], requires_grad=True)
# hypothesis= tensor([[0.9517],
#         [0.9930],
#         [0.9813],
#         [0.9974]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.9945, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 3
# w= tensor([[0.9700],
#         [1.9700]], requires_grad=True)
# b= tensor([2.9700], requires_grad=True)
# hypothesis= tensor([[0.9512],
#         [0.9929],
#         [0.9809],
#         [0.9973]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.9823, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4
# w= tensor([[0.9600],
#         [1.9600]], requires_grad=True)
# b= tensor([2.9600], requires_grad=True)
# hypothesis= tensor([[0.9507],
#         [0.9928],
#         [0.9805],
#         [0.9972]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.9701, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 5
# w= tensor([[0.9500],
#         [1.9500]], requires_grad=True)
# b= tensor([2.9500], requires_grad=True)
# hypothesis= tensor([[0.9503],
#         [0.9926],
#         [0.9802],
#         [0.9971]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.9578, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 6
# w= tensor([[0.9400],
#         [1.9400]], requires_grad=True)
# b= tensor([2.9400], requires_grad=True)
# hypothesis= tensor([[0.9498],
#         [0.9925],
#         [0.9798],
#         [0.9970]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.9456, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 7
# w= tensor([[0.9300],
#         [1.9300]], requires_grad=True)
# b= tensor([2.9300], requires_grad=True)
# hypothesis= tensor([[0.9493],
#         [0.9923],
#         [0.9794],
#         [0.9970]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.9334, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 8
# w= tensor([[0.9200],
#         [1.9200]], requires_grad=True)
# b= tensor([2.9200], requires_grad=True)
# hypothesis= tensor([[0.9488],
#         [0.9922],
#         [0.9790],
#         [0.9969]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.9212, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 9
# w= tensor([[0.9100],
#         [1.9100]], requires_grad=True)
# b= tensor([2.9100], requires_grad=True)
# hypothesis= tensor([[0.9483],
#         [0.9920],
#         [0.9785],
#         [0.9968]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.9090, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 10
# w= tensor([[0.9000],
#         [1.9000]], requires_grad=True)
# b= tensor([2.9000], requires_grad=True)
# hypothesis= tensor([[0.9478],
#         [0.9918],
#         [0.9781],
#         [0.9967]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.8968, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 11
# w= tensor([[0.8900],
#         [1.8900]], requires_grad=True)
# b= tensor([2.8900], requires_grad=True)
# hypothesis= tensor([[0.9474],
#         [0.9917],
#         [0.9777],
#         [0.9966]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.8846, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 12
# w= tensor([[0.8800],
#         [1.8800]], requires_grad=True)
# b= tensor([2.8800], requires_grad=True)
# hypothesis= tensor([[0.9468],
#         [0.9915],
#         [0.9772],
#         [0.9965]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.8725, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 13
# w= tensor([[0.8700],
#         [1.8700]], requires_grad=True)
# b= tensor([2.8700], requires_grad=True)
# hypothesis= tensor([[0.9463],
#         [0.9913],
#         [0.9768],
#         [0.9964]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.8603, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 14
# w= tensor([[0.8600],
#         [1.8600]], requires_grad=True)
# b= tensor([2.8600], requires_grad=True)
# hypothesis= tensor([[0.9458],
#         [0.9912],
#         [0.9763],
#         [0.9962]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.8481, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 15
# w= tensor([[0.8501],
#         [1.8500]], requires_grad=True)
# b= tensor([2.8500], requires_grad=True)
# hypothesis= tensor([[0.9453],
#         [0.9910],
#         [0.9759],
#         [0.9961]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.8359, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 16
# w= tensor([[0.8401],
#         [1.8400]], requires_grad=True)
# b= tensor([2.8400], requires_grad=True)
# hypothesis= tensor([[0.9448],
#         [0.9908],
#         [0.9754],
#         [0.9960]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.8238, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 17
# w= tensor([[0.8301],
#         [1.8300]], requires_grad=True)
# b= tensor([2.8301], requires_grad=True)
# hypothesis= tensor([[0.9443],
#         [0.9906],
#         [0.9749],
#         [0.9959]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.8116, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 18
# w= tensor([[0.8201],
#         [1.8200]], requires_grad=True)
# b= tensor([2.8201], requires_grad=True)
# hypothesis= tensor([[0.9438],
#         [0.9904],
#         [0.9744],
#         [0.9958]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.7995, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 19
# w= tensor([[0.8101],
#         [1.8101]], requires_grad=True)
# b= tensor([2.8101], requires_grad=True)
# hypothesis= tensor([[0.9432],
#         [0.9902],
#         [0.9739],
#         [0.9956]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.7874, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 20
# w= tensor([[0.8001],
#         [1.8001]], requires_grad=True)
# b= tensor([2.8001], requires_grad=True)
# hypothesis= tensor([[0.9427],
#         [0.9900],
#         [0.9734],
#         [0.9955]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.7752, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 21
# w= tensor([[0.7901],
#         [1.7901]], requires_grad=True)
# b= tensor([2.7901], requires_grad=True)
# hypothesis= tensor([[0.9421],
#         [0.9899],
#         [0.9729],
#         [0.9954]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.7631, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 22
# w= tensor([[0.7802],
#         [1.7801]], requires_grad=True)
# b= tensor([2.7801], requires_grad=True)
# hypothesis= tensor([[0.9416],
#         [0.9896],
#         [0.9724],
#         [0.9952]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.7510, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 23
# w= tensor([[0.7702],
#         [1.7701]], requires_grad=True)
# b= tensor([2.7701], requires_grad=True)
# hypothesis= tensor([[0.9410],
#         [0.9894],
#         [0.9718],
#         [0.9951]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.7389, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 24
# w= tensor([[0.7602],
#         [1.7601]], requires_grad=True)
# b= tensor([2.7602], requires_grad=True)
# hypothesis= tensor([[0.9405],
#         [0.9892],
#         [0.9713],
#         [0.9949]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.7268, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 25
# w= tensor([[0.7502],
#         [1.7501]], requires_grad=True)
# b= tensor([2.7502], requires_grad=True)
# hypothesis= tensor([[0.9399],
#         [0.9890],
#         [0.9707],
#         [0.9948]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.7147, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 26
# w= tensor([[0.7403],
#         [1.7401]], requires_grad=True)
# b= tensor([2.7402], requires_grad=True)
# hypothesis= tensor([[0.9394],
#         [0.9888],
#         [0.9701],
#         [0.9946]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.7026, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 27
# w= tensor([[0.7303],
#         [1.7302]], requires_grad=True)
# b= tensor([2.7302], requires_grad=True)
# hypothesis= tensor([[0.9388],
#         [0.9886],
#         [0.9695],
#         [0.9945]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.6906, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 28
# w= tensor([[0.7203],
#         [1.7202]], requires_grad=True)
# b= tensor([2.7203], requires_grad=True)
# hypothesis= tensor([[0.9382],
#         [0.9883],
#         [0.9689],
#         [0.9943]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.6785, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 29
# w= tensor([[0.7104],
#         [1.7102]], requires_grad=True)
# b= tensor([2.7103], requires_grad=True)
# hypothesis= tensor([[0.9376],
#         [0.9881],
#         [0.9683],
#         [0.9941]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.6665, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 30
# w= tensor([[0.7004],
#         [1.7002]], requires_grad=True)
# b= tensor([2.7003], requires_grad=True)
# hypothesis= tensor([[0.9370],
#         [0.9879],
#         [0.9677],
#         [0.9939]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.6544, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 31
# w= tensor([[0.6905],
#         [1.6902]], requires_grad=True)
# b= tensor([2.6903], requires_grad=True)
# hypothesis= tensor([[0.9365],
#         [0.9876],
#         [0.9671],
#         [0.9938]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.6424, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 32
# w= tensor([[0.6805],
#         [1.6803]], requires_grad=True)
# b= tensor([2.6804], requires_grad=True)
# hypothesis= tensor([[0.9359],
#         [0.9874],
#         [0.9665],
#         [0.9936]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.6304, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 33
# w= tensor([[0.6706],
#         [1.6703]], requires_grad=True)
# b= tensor([2.6704], requires_grad=True)
# hypothesis= tensor([[0.9353],
#         [0.9871],
#         [0.9658],
#         [0.9934]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.6184, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 34
# w= tensor([[0.6606],
#         [1.6603]], requires_grad=True)
# b= tensor([2.6605], requires_grad=True)
# hypothesis= tensor([[0.9347],
#         [0.9869],
#         [0.9651],
#         [0.9932]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.6064, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 35
# w= tensor([[0.6507],
#         [1.6503]], requires_grad=True)
# b= tensor([2.6505], requires_grad=True)
# hypothesis= tensor([[0.9340],
#         [0.9866],
#         [0.9645],
#         [0.9930]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.5944, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 36
# w= tensor([[0.6407],
#         [1.6404]], requires_grad=True)
# b= tensor([2.6405], requires_grad=True)
# hypothesis= tensor([[0.9334],
#         [0.9864],
#         [0.9638],
#         [0.9928]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.5824, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 37
# w= tensor([[0.6308],
#         [1.6304]], requires_grad=True)
# b= tensor([2.6306], requires_grad=True)
# hypothesis= tensor([[0.9328],
#         [0.9861],
#         [0.9631],
#         [0.9925]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.5704, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 38
# w= tensor([[0.6209],
#         [1.6204]], requires_grad=True)
# b= tensor([2.6206], requires_grad=True)
# hypothesis= tensor([[0.9322],
#         [0.9858],
#         [0.9624],
#         [0.9923]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.5585, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 39
# w= tensor([[0.6110],
#         [1.6105]], requires_grad=True)
# b= tensor([2.6107], requires_grad=True)
# hypothesis= tensor([[0.9315],
#         [0.9855],
#         [0.9616],
#         [0.9921]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.5465, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 40
# w= tensor([[0.6010],
#         [1.6005]], requires_grad=True)
# b= tensor([2.6007], requires_grad=True)
# hypothesis= tensor([[0.9309],
#         [0.9852],
#         [0.9609],
#         [0.9919]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.5346, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 41
# w= tensor([[0.5911],
#         [1.5906]], requires_grad=True)
# b= tensor([2.5908], requires_grad=True)
# hypothesis= tensor([[0.9303],
#         [0.9850],
#         [0.9601],
#         [0.9916]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.5227, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 42
# w= tensor([[0.5812],
#         [1.5806]], requires_grad=True)
# b= tensor([2.5809], requires_grad=True)
# hypothesis= tensor([[0.9296],
#         [0.9847],
#         [0.9594],
#         [0.9914]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.5107, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 43
# w= tensor([[0.5713],
#         [1.5706]], requires_grad=True)
# b= tensor([2.5709], requires_grad=True)
# hypothesis= tensor([[0.9290],
#         [0.9844],
#         [0.9586],
#         [0.9911]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.4989, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 44
# w= tensor([[0.5614],
#         [1.5607]], requires_grad=True)
# b= tensor([2.5610], requires_grad=True)
# hypothesis= tensor([[0.9283],
#         [0.9840],
#         [0.9578],
#         [0.9908]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.4870, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 45
# w= tensor([[0.5515],
#         [1.5507]], requires_grad=True)
# b= tensor([2.5511], requires_grad=True)
# hypothesis= tensor([[0.9276],
#         [0.9837],
#         [0.9570],
#         [0.9906]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.4751, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 46
# w= tensor([[0.5416],
#         [1.5408]], requires_grad=True)
# b= tensor([2.5411], requires_grad=True)
# hypothesis= tensor([[0.9270],
#         [0.9834],
#         [0.9562],
#         [0.9903]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.4632, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 47
# w= tensor([[0.5317],
#         [1.5309]], requires_grad=True)
# b= tensor([2.5312], requires_grad=True)
# hypothesis= tensor([[0.9263],
#         [0.9831],
#         [0.9553],
#         [0.9900]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.4514, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 48
# w= tensor([[0.5218],
#         [1.5209]], requires_grad=True)
# b= tensor([2.5213], requires_grad=True)
# hypothesis= tensor([[0.9256],
#         [0.9827],
#         [0.9545],
#         [0.9897]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.4396, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 49
# w= tensor([[0.5120],
#         [1.5110]], requires_grad=True)
# b= tensor([2.5114], requires_grad=True)
# hypothesis= tensor([[0.9249],
#         [0.9824],
#         [0.9536],
#         [0.9894]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.4278, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 50
# w= tensor([[0.5021],
#         [1.5010]], requires_grad=True)
# b= tensor([2.5015], requires_grad=True)
# hypothesis= tensor([[0.9242],
#         [0.9821],
#         [0.9527],
#         [0.9891]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.4160, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 51
# w= tensor([[0.4922],
#         [1.4911]], requires_grad=True)
# b= tensor([2.4916], requires_grad=True)
# hypothesis= tensor([[0.9235],
#         [0.9817],
#         [0.9518],
#         [0.9887]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.4042, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 52
# w= tensor([[0.4824],
#         [1.4812]], requires_grad=True)
# b= tensor([2.4817], requires_grad=True)
# hypothesis= tensor([[0.9228],
#         [0.9813],
#         [0.9509],
#         [0.9884]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.3924, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 53
# w= tensor([[0.4725],
#         [1.4713]], requires_grad=True)
# b= tensor([2.4717], requires_grad=True)
# hypothesis= tensor([[0.9221],
#         [0.9810],
#         [0.9500],
#         [0.9881]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.3807, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 54
# w= tensor([[0.4627],
#         [1.4613]], requires_grad=True)
# b= tensor([2.4619], requires_grad=True)
# hypothesis= tensor([[0.9214],
#         [0.9806],
#         [0.9490],
#         [0.9877]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.3689, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 55
# w= tensor([[0.4528],
#         [1.4514]], requires_grad=True)
# b= tensor([2.4520], requires_grad=True)
# hypothesis= tensor([[0.9207],
#         [0.9802],
#         [0.9481],
#         [0.9873]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.3572, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 56
# w= tensor([[0.4430],
#         [1.4415]], requires_grad=True)
# b= tensor([2.4421], requires_grad=True)
# hypothesis= tensor([[0.9200],
#         [0.9798],
#         [0.9471],
#         [0.9870]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.3455, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 57
# w= tensor([[0.4332],
#         [1.4316]], requires_grad=True)
# b= tensor([2.4322], requires_grad=True)
# hypothesis= tensor([[0.9192],
#         [0.9794],
#         [0.9461],
#         [0.9866]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.3338, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 58
# w= tensor([[0.4233],
#         [1.4217]], requires_grad=True)
# b= tensor([2.4223], requires_grad=True)
# hypothesis= tensor([[0.9185],
#         [0.9790],
#         [0.9451],
#         [0.9862]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.3221, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 59
# w= tensor([[0.4135],
#         [1.4118]], requires_grad=True)
# b= tensor([2.4124], requires_grad=True)
# hypothesis= tensor([[0.9178],
#         [0.9786],
#         [0.9441],
#         [0.9858]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.3105, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 60
# w= tensor([[0.4037],
#         [1.4019]], requires_grad=True)
# b= tensor([2.4025], requires_grad=True)
# hypothesis= tensor([[0.9170],
#         [0.9782],
#         [0.9430],
#         [0.9853]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.2988, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 61
# w= tensor([[0.3939],
#         [1.3920]], requires_grad=True)
# b= tensor([2.3927], requires_grad=True)
# hypothesis= tensor([[0.9163],
#         [0.9778],
#         [0.9419],
#         [0.9849]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.2872, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 62
# w= tensor([[0.3841],
#         [1.3821]], requires_grad=True)
# b= tensor([2.3828], requires_grad=True)
# hypothesis= tensor([[0.9155],
#         [0.9774],
#         [0.9409],
#         [0.9845]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.2756, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 63
# w= tensor([[0.3744],
#         [1.3722]], requires_grad=True)
# b= tensor([2.3730], requires_grad=True)
# hypothesis= tensor([[0.9147],
#         [0.9769],
#         [0.9398],
#         [0.9840]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.2640, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 64
# w= tensor([[0.3646],
#         [1.3623]], requires_grad=True)
# b= tensor([2.3631], requires_grad=True)
# hypothesis= tensor([[0.9140],
#         [0.9765],
#         [0.9386],
#         [0.9835]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.2525, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 65
# w= tensor([[0.3548],
#         [1.3525]], requires_grad=True)
# b= tensor([2.3533], requires_grad=True)
# hypothesis= tensor([[0.9132],
#         [0.9760],
#         [0.9375],
#         [0.9831]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.2409, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 66
# w= tensor([[0.3451],
#         [1.3426]], requires_grad=True)
# b= tensor([2.3434], requires_grad=True)
# hypothesis= tensor([[0.9124],
#         [0.9755],
#         [0.9363],
#         [0.9826]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.2294, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 67
# w= tensor([[0.3353],
#         [1.3327]], requires_grad=True)
# b= tensor([2.3336], requires_grad=True)
# hypothesis= tensor([[0.9116],
#         [0.9751],
#         [0.9352],
#         [0.9820]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.2179, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 68
# w= tensor([[0.3256],
#         [1.3229]], requires_grad=True)
# b= tensor([2.3237], requires_grad=True)
# hypothesis= tensor([[0.9108],
#         [0.9746],
#         [0.9340],
#         [0.9815]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.2064, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 69
# w= tensor([[0.3158],
#         [1.3130]], requires_grad=True)
# b= tensor([2.3139], requires_grad=True)
# hypothesis= tensor([[0.9100],
#         [0.9741],
#         [0.9328],
#         [0.9810]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.1950, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 70
# w= tensor([[0.3061],
#         [1.3032]], requires_grad=True)
# b= tensor([2.3041], requires_grad=True)
# hypothesis= tensor([[0.9092],
#         [0.9736],
#         [0.9315],
#         [0.9804]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.1836, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 71
# w= tensor([[0.2964],
#         [1.2933]], requires_grad=True)
# b= tensor([2.2943], requires_grad=True)
# hypothesis= tensor([[0.9084],
#         [0.9731],
#         [0.9303],
#         [0.9798]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.1721, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 72
# w= tensor([[0.2867],
#         [1.2835]], requires_grad=True)
# b= tensor([2.2845], requires_grad=True)
# hypothesis= tensor([[0.9076],
#         [0.9726],
#         [0.9290],
#         [0.9793]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.1607, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 73
# w= tensor([[0.2770],
#         [1.2736]], requires_grad=True)
# b= tensor([2.2747], requires_grad=True)
# hypothesis= tensor([[0.9068],
#         [0.9720],
#         [0.9277],
#         [0.9787]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.1494, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 74
# w= tensor([[0.2673],
#         [1.2638]], requires_grad=True)
# b= tensor([2.2649], requires_grad=True)
# hypothesis= tensor([[0.9059],
#         [0.9715],
#         [0.9264],
#         [0.9780]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.1380, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 75
# w= tensor([[0.2577],
#         [1.2540]], requires_grad=True)
# b= tensor([2.2551], requires_grad=True)
# hypothesis= tensor([[0.9051],
#         [0.9709],
#         [0.9250],
#         [0.9774]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.1267, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 76
# w= tensor([[0.2480],
#         [1.2442]], requires_grad=True)
# b= tensor([2.2453], requires_grad=True)
# hypothesis= tensor([[0.9042],
#         [0.9704],
#         [0.9237],
#         [0.9767]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.1154, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 77
# w= tensor([[0.2384],
#         [1.2344]], requires_grad=True)
# b= tensor([2.2355], requires_grad=True)
# hypothesis= tensor([[0.9034],
#         [0.9698],
#         [0.9223],
#         [0.9761]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.1041, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 78
# w= tensor([[0.2287],
#         [1.2246]], requires_grad=True)
# b= tensor([2.2257], requires_grad=True)
# hypothesis= tensor([[0.9025],
#         [0.9692],
#         [0.9209],
#         [0.9754]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.0929, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 79
# w= tensor([[0.2191],
#         [1.2148]], requires_grad=True)
# b= tensor([2.2159], requires_grad=True)
# hypothesis= tensor([[0.9017],
#         [0.9687],
#         [0.9195],
#         [0.9747]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.0817, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 80
# w= tensor([[0.2095],
#         [1.2050]], requires_grad=True)
# b= tensor([2.2062], requires_grad=True)
# hypothesis= tensor([[0.9008],
#         [0.9681],
#         [0.9180],
#         [0.9739]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.0705, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 81
# w= tensor([[0.1999],
#         [1.1952]], requires_grad=True)
# b= tensor([2.1964], requires_grad=True)
# hypothesis= tensor([[0.8999],
#         [0.9674],
#         [0.9165],
#         [0.9732]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.0593, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 82
# w= tensor([[0.1903],
#         [1.1854]], requires_grad=True)
# b= tensor([2.1867], requires_grad=True)
# hypothesis= tensor([[0.8990],
#         [0.9668],
#         [0.9151],
#         [0.9724]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.0482, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 83
# w= tensor([[0.1808],
#         [1.1757]], requires_grad=True)
# b= tensor([2.1769], requires_grad=True)
# hypothesis= tensor([[0.8982],
#         [0.9662],
#         [0.9135],
#         [0.9716]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.0371, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 84
# w= tensor([[0.1712],
#         [1.1659]], requires_grad=True)
# b= tensor([2.1672], requires_grad=True)
# hypothesis= tensor([[0.8973],
#         [0.9655],
#         [0.9120],
#         [0.9708]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.0260, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 85
# w= tensor([[0.1617],
#         [1.1562]], requires_grad=True)
# b= tensor([2.1575], requires_grad=True)
# hypothesis= tensor([[0.8964],
#         [0.9649],
#         [0.9104],
#         [0.9700]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.0149, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 86
# w= tensor([[0.1521],
#         [1.1464]], requires_grad=True)
# b= tensor([2.1478], requires_grad=True)
# hypothesis= tensor([[0.8955],
#         [0.9642],
#         [0.9089],
#         [0.9691]], grad_fn=<SigmoidBackward0>)
# cost= tensor(2.0039, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 87
# w= tensor([[0.1426],
#         [1.1367]], requires_grad=True)
# b= tensor([2.1381], requires_grad=True)
# hypothesis= tensor([[0.8945],
#         [0.9636],
#         [0.9073],
#         [0.9682]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.9929, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 88
# w= tensor([[0.1331],
#         [1.1270]], requires_grad=True)
# b= tensor([2.1283], requires_grad=True)
# hypothesis= tensor([[0.8936],
#         [0.9629],
#         [0.9056],
#         [0.9673]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.9819, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 89
# w= tensor([[0.1236],
#         [1.1173]], requires_grad=True)
# b= tensor([2.1187], requires_grad=True)
# hypothesis= tensor([[0.8927],
#         [0.9622],
#         [0.9040],
#         [0.9664]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.9710, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 90
# w= tensor([[0.1142],
#         [1.1076]], requires_grad=True)
# b= tensor([2.1090], requires_grad=True)
# hypothesis= tensor([[0.8918],
#         [0.9615],
#         [0.9023],
#         [0.9655]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.9601, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 91
# w= tensor([[0.1047],
#         [1.0979]], requires_grad=True)
# b= tensor([2.0993], requires_grad=True)
# hypothesis= tensor([[0.8908],
#         [0.9607],
#         [0.9006],
#         [0.9645]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.9492, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 92
# w= tensor([[0.0953],
#         [1.0882]], requires_grad=True)
# b= tensor([2.0896], requires_grad=True)
# hypothesis= tensor([[0.8899],
#         [0.9600],
#         [0.8989],
#         [0.9635]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.9384, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 93
# w= tensor([[0.0858],
#         [1.0785]], requires_grad=True)
# b= tensor([2.0800], requires_grad=True)
# hypothesis= tensor([[0.8889],
#         [0.9592],
#         [0.8971],
#         [0.9625]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.9276, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 94
# w= tensor([[0.0764],
#         [1.0688]], requires_grad=True)
# b= tensor([2.0703], requires_grad=True)
# hypothesis= tensor([[0.8880],
#         [0.9585],
#         [0.8954],
#         [0.9614]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.9168, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 95
# w= tensor([[0.0671],
#         [1.0592]], requires_grad=True)
# b= tensor([2.0607], requires_grad=True)
# hypothesis= tensor([[0.8870],
#         [0.9577],
#         [0.8936],
#         [0.9603]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.9061, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 96
# w= tensor([[0.0577],
#         [1.0495]], requires_grad=True)
# b= tensor([2.0510], requires_grad=True)
# hypothesis= tensor([[0.8861],
#         [0.9569],
#         [0.8917],
#         [0.9592]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.8954, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 97
# w= tensor([[0.0483],
#         [1.0399]], requires_grad=True)
# b= tensor([2.0414], requires_grad=True)
# hypothesis= tensor([[0.8851],
#         [0.9561],
#         [0.8899],
#         [0.9581]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.8847, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 98
# w= tensor([[0.0390],
#         [1.0303]], requires_grad=True)
# b= tensor([2.0318], requires_grad=True)
# hypothesis= tensor([[0.8841],
#         [0.9553],
#         [0.8880],
#         [0.9569]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.8741, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 99
# w= tensor([[0.0297],
#         [1.0207]], requires_grad=True)
# b= tensor([2.0222], requires_grad=True)
# hypothesis= tensor([[0.8831],
#         [0.9545],
#         [0.8861],
#         [0.9557]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.8635, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 100
# w= tensor([[0.0204],
#         [1.0111]], requires_grad=True)
# b= tensor([2.0126], requires_grad=True)
# hypothesis= tensor([[0.8821],
#         [0.9536],
#         [0.8842],
#         [0.9545]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.8529, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 101
# w= tensor([[0.0111],
#         [1.0015]], requires_grad=True)
# b= tensor([2.0030], requires_grad=True)
# hypothesis= tensor([[0.8811],
#         [0.9528],
#         [0.8823],
#         [0.9533]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.8424, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 102
# w= tensor([[0.0019],
#         [0.9919]], requires_grad=True)
# b= tensor([1.9934], requires_grad=True)
# hypothesis= tensor([[0.8801],
#         [0.9519],
#         [0.8803],
#         [0.9520]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.8319, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 103
# w= tensor([[-0.0074],
#         [ 0.9824]], requires_grad=True)
# b= tensor([1.9838], requires_grad=True)
# hypothesis= tensor([[0.8791],
#         [0.9510],
#         [0.8783],
#         [0.9507]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.8215, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 104
# w= tensor([[-0.0166],
#         [ 0.9728]], requires_grad=True)
# b= tensor([1.9743], requires_grad=True)
# hypothesis= tensor([[0.8781],
#         [0.9501],
#         [0.8763],
#         [0.9493]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.8111, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 105
# w= tensor([[-0.0258],
#         [ 0.9633]], requires_grad=True)
# b= tensor([1.9647], requires_grad=True)
# hypothesis= tensor([[0.8770],
#         [0.9492],
#         [0.8742],
#         [0.9480]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.8007, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 106
# w= tensor([[-0.0349],
#         [ 0.9538]], requires_grad=True)
# b= tensor([1.9552], requires_grad=True)
# hypothesis= tensor([[0.8760],
#         [0.9483],
#         [0.8722],
#         [0.9465]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.7904, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 107
# w= tensor([[-0.0441],
#         [ 0.9443]], requires_grad=True)
# b= tensor([1.9457], requires_grad=True)
# hypothesis= tensor([[0.8750],
#         [0.9473],
#         [0.8701],
#         [0.9451]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.7801, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 108
# w= tensor([[-0.0532],
#         [ 0.9348]], requires_grad=True)
# b= tensor([1.9362], requires_grad=True)
# hypothesis= tensor([[0.8739],
#         [0.9464],
#         [0.8680],
#         [0.9436]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.7699, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 109
# w= tensor([[-0.0623],
#         [ 0.9253]], requires_grad=True)
# b= tensor([1.9267], requires_grad=True)
# hypothesis= tensor([[0.8729],
#         [0.9454],
#         [0.8658],
#         [0.9421]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.7597, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 110
# w= tensor([[-0.0714],
#         [ 0.9158]], requires_grad=True)
# b= tensor([1.9172], requires_grad=True)
# hypothesis= tensor([[0.8718],
#         [0.9444],
#         [0.8636],
#         [0.9406]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.7496, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 111
# w= tensor([[-0.0804],
#         [ 0.9064]], requires_grad=True)
# b= tensor([1.9077], requires_grad=True)
# hypothesis= tensor([[0.8708],
#         [0.9434],
#         [0.8614],
#         [0.9390]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.7395, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 112
# w= tensor([[-0.0894],
#         [ 0.8970]], requires_grad=True)
# b= tensor([1.8983], requires_grad=True)
# hypothesis= tensor([[0.8697],
#         [0.9424],
#         [0.8592],
#         [0.9374]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.7294, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 113
# w= tensor([[-0.0984],
#         [ 0.8875]], requires_grad=True)
# b= tensor([1.8888], requires_grad=True)
# hypothesis= tensor([[0.8686],
#         [0.9414],
#         [0.8570],
#         [0.9357]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.7194, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 114
# w= tensor([[-0.1074],
#         [ 0.8781]], requires_grad=True)
# b= tensor([1.8794], requires_grad=True)
# hypothesis= tensor([[0.8675],
#         [0.9403],
#         [0.8547],
#         [0.9340]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.7094, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 115
# w= tensor([[-0.1164],
#         [ 0.8688]], requires_grad=True)
# b= tensor([1.8699], requires_grad=True)
# hypothesis= tensor([[0.8665],
#         [0.9393],
#         [0.8524],
#         [0.9323]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.6995, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 116
# w= tensor([[-0.1253],
#         [ 0.8594]], requires_grad=True)
# b= tensor([1.8605], requires_grad=True)
# hypothesis= tensor([[0.8654],
#         [0.9382],
#         [0.8501],
#         [0.9305]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.6896, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 117
# w= tensor([[-0.1342],
#         [ 0.8501]], requires_grad=True)
# b= tensor([1.8511], requires_grad=True)
# hypothesis= tensor([[0.8643],
#         [0.9371],
#         [0.8477],
#         [0.9287]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.6798, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 118
# w= tensor([[-0.1430],
#         [ 0.8407]], requires_grad=True)
# b= tensor([1.8417], requires_grad=True)
# hypothesis= tensor([[0.8632],
#         [0.9360],
#         [0.8454],
#         [0.9269]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.6701, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 119
# w= tensor([[-0.1519],
#         [ 0.8314]], requires_grad=True)
# b= tensor([1.8324], requires_grad=True)
# hypothesis= tensor([[0.8620],
#         [0.9349],
#         [0.8430],
#         [0.9250]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.6603, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 120
# w= tensor([[-0.1607],
#         [ 0.8222]], requires_grad=True)
# b= tensor([1.8230], requires_grad=True)
# hypothesis= tensor([[0.8609],
#         [0.9337],
#         [0.8406],
#         [0.9230]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.6507, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 121
# w= tensor([[-0.1694],
#         [ 0.8129]], requires_grad=True)
# b= tensor([1.8137], requires_grad=True)
# hypothesis= tensor([[0.8598],
#         [0.9326],
#         [0.8381],
#         [0.9211]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.6410, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 122
# w= tensor([[-0.1782],
#         [ 0.8036]], requires_grad=True)
# b= tensor([1.8043], requires_grad=True)
# hypothesis= tensor([[0.8587],
#         [0.9314],
#         [0.8356],
#         [0.9191]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.6315, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 123
# w= tensor([[-0.1869],
#         [ 0.7944]], requires_grad=True)
# b= tensor([1.7950], requires_grad=True)
# hypothesis= tensor([[0.8575],
#         [0.9302],
#         [0.8332],
#         [0.9170]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.6220, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 124
# w= tensor([[-0.1956],
#         [ 0.7852]], requires_grad=True)
# b= tensor([1.7857], requires_grad=True)
# hypothesis= tensor([[0.8564],
#         [0.9290],
#         [0.8306],
#         [0.9149]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.6125, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 125
# w= tensor([[-0.2042],
#         [ 0.7760]], requires_grad=True)
# b= tensor([1.7764], requires_grad=True)
# hypothesis= tensor([[0.8553],
#         [0.9277],
#         [0.8281],
#         [0.9128]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.6031, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 126
# w= tensor([[-0.2128],
#         [ 0.7669]], requires_grad=True)
# b= tensor([1.7672], requires_grad=True)
# hypothesis= tensor([[0.8541],
#         [0.9265],
#         [0.8255],
#         [0.9106]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.5937, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 127
# w= tensor([[-0.2214],
#         [ 0.7577]], requires_grad=True)
# b= tensor([1.7579], requires_grad=True)
# hypothesis= tensor([[0.8530],
#         [0.9252],
#         [0.8230],
#         [0.9084]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.5845, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 128
# w= tensor([[-0.2299],
#         [ 0.7486]], requires_grad=True)
# b= tensor([1.7487], requires_grad=True)
# hypothesis= tensor([[0.8518],
#         [0.9240],
#         [0.8204],
#         [0.9061]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.5752, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 129
# w= tensor([[-0.2384],
#         [ 0.7395]], requires_grad=True)
# b= tensor([1.7395], requires_grad=True)
# hypothesis= tensor([[0.8506],
#         [0.9227],
#         [0.8177],
#         [0.9038]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.5660, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 130
# w= tensor([[-0.2469],
#         [ 0.7305]], requires_grad=True)
# b= tensor([1.7303], requires_grad=True)
# hypothesis= tensor([[0.8494],
#         [0.9213],
#         [0.8151],
#         [0.9015]], grad_fn=<SigmoidBackward0>)
# cost= tensor(1.5569, grad_fn=<MeanBackward0>)
# ...
# cost= tensor(0.0219, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4959
# w= tensor([[7.0013],
#         [6.9927]], requires_grad=True)
# b= tensor([-10.5670], requires_grad=True)
# hypothesis= tensor([[2.5752e-05],
#         [2.7272e-02],
#         [2.7499e-02],
#         [9.6854e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0219, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4960
# w= tensor([[7.0024],
#         [6.9938]], requires_grad=True)
# b= tensor([-10.5687], requires_grad=True)
# hypothesis= tensor([[2.5708e-05],
#         [2.7256e-02],
#         [2.7484e-02],
#         [9.6855e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0219, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4961
# w= tensor([[7.0035],
#         [6.9950]], requires_grad=True)
# b= tensor([-10.5704], requires_grad=True)
# hypothesis= tensor([[2.5665e-05],
#         [2.7241e-02],
#         [2.7469e-02],
#         [9.6857e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0219, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4962
# w= tensor([[7.0047],
#         [6.9961]], requires_grad=True)
# b= tensor([-10.5721], requires_grad=True)
# hypothesis= tensor([[2.5621e-05],
#         [2.7226e-02],
#         [2.7454e-02],
#         [9.6859e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0218, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4963
# w= tensor([[7.0058],
#         [6.9972]], requires_grad=True)
# b= tensor([-10.5738], requires_grad=True)
# hypothesis= tensor([[2.5578e-05],
#         [2.7212e-02],
#         [2.7439e-02],
#         [9.6861e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0218, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4964
# w= tensor([[7.0069],
#         [6.9984]], requires_grad=True)
# b= tensor([-10.5755], requires_grad=True)
# hypothesis= tensor([[2.5534e-05],
#         [2.7197e-02],
#         [2.7424e-02],
#         [9.6862e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0218, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4965
# w= tensor([[7.0081],
#         [6.9995]], requires_grad=True)
# b= tensor([-10.5772], requires_grad=True)
# hypothesis= tensor([[2.5491e-05],
#         [2.7182e-02],
#         [2.7409e-02],
#         [9.6864e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0218, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4966
# w= tensor([[7.0092],
#         [7.0006]], requires_grad=True)
# b= tensor([-10.5789], requires_grad=True)
# hypothesis= tensor([[2.5447e-05],
#         [2.7167e-02],
#         [2.7394e-02],
#         [9.6866e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0218, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4967
# w= tensor([[7.0103],
#         [7.0018]], requires_grad=True)
# b= tensor([-10.5806], requires_grad=True)
# hypothesis= tensor([[2.5404e-05],
#         [2.7152e-02],
#         [2.7378e-02],
#         [9.6868e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0218, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4968
# w= tensor([[7.0115],
#         [7.0029]], requires_grad=True)
# b= tensor([-10.5823], requires_grad=True)
# hypothesis= tensor([[2.5361e-05],
#         [2.7137e-02],
#         [2.7363e-02],
#         [9.6869e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0218, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4969
# w= tensor([[7.0126],
#         [7.0041]], requires_grad=True)
# b= tensor([-10.5840], requires_grad=True)
# hypothesis= tensor([[2.5318e-05],
#         [2.7122e-02],
#         [2.7348e-02],
#         [9.6871e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0218, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4970
# w= tensor([[7.0137],
#         [7.0052]], requires_grad=True)
# b= tensor([-10.5857], requires_grad=True)
# hypothesis= tensor([[2.5275e-05],
#         [2.7107e-02],
#         [2.7333e-02],
#         [9.6873e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0217, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4971
# w= tensor([[7.0149],
#         [7.0063]], requires_grad=True)
# b= tensor([-10.5874], requires_grad=True)
# hypothesis= tensor([[2.5232e-05],
#         [2.7092e-02],
#         [2.7318e-02],
#         [9.6874e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0217, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4972
# w= tensor([[7.0160],
#         [7.0075]], requires_grad=True)
# b= tensor([-10.5891], requires_grad=True)
# hypothesis= tensor([[2.5189e-05],
#         [2.7077e-02],
#         [2.7303e-02],
#         [9.6876e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0217, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4973
# w= tensor([[7.0171],
#         [7.0086]], requires_grad=True)
# b= tensor([-10.5908], requires_grad=True)
# hypothesis= tensor([[2.5146e-05],
#         [2.7062e-02],
#         [2.7288e-02],
#         [9.6878e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0217, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4974
# w= tensor([[7.0183],
#         [7.0097]], requires_grad=True)
# b= tensor([-10.5925], requires_grad=True)
# hypothesis= tensor([[2.5104e-05],
#         [2.7047e-02],
#         [2.7273e-02],
#         [9.6880e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0217, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4975
# w= tensor([[7.0194],
#         [7.0109]], requires_grad=True)
# b= tensor([-10.5942], requires_grad=True)
# hypothesis= tensor([[2.5061e-05],
#         [2.7032e-02],
#         [2.7258e-02],
#         [9.6881e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0217, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4976
# w= tensor([[7.0205],
#         [7.0120]], requires_grad=True)
# b= tensor([-10.5959], requires_grad=True)
# hypothesis= tensor([[2.5019e-05],
#         [2.7018e-02],
#         [2.7243e-02],
#         [9.6883e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0217, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4977
# w= tensor([[7.0217],
#         [7.0131]], requires_grad=True)
# b= tensor([-10.5976], requires_grad=True)
# hypothesis= tensor([[2.4976e-05],
#         [2.7003e-02],
#         [2.7228e-02],
#         [9.6885e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0217, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4978
# w= tensor([[7.0228],
#         [7.0143]], requires_grad=True)
# b= tensor([-10.5993], requires_grad=True)
# hypothesis= tensor([[2.4934e-05],
#         [2.6988e-02],
#         [2.7213e-02],
#         [9.6887e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0217, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4979
# w= tensor([[7.0239],
#         [7.0154]], requires_grad=True)
# b= tensor([-10.6010], requires_grad=True)
# hypothesis= tensor([[2.4891e-05],
#         [2.6973e-02],
#         [2.7198e-02],
#         [9.6888e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0216, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4980
# w= tensor([[7.0251],
#         [7.0165]], requires_grad=True)
# b= tensor([-10.6027], requires_grad=True)
# hypothesis= tensor([[2.4849e-05],
#         [2.6958e-02],
#         [2.7183e-02],
#         [9.6890e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0216, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4981
# w= tensor([[7.0262],
#         [7.0177]], requires_grad=True)
# b= tensor([-10.6044], requires_grad=True)
# hypothesis= tensor([[2.4807e-05],
#         [2.6943e-02],
#         [2.7168e-02],
#         [9.6892e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0216, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4982
# w= tensor([[7.0273],
#         [7.0188]], requires_grad=True)
# b= tensor([-10.6061], requires_grad=True)
# hypothesis= tensor([[2.4765e-05],
#         [2.6929e-02],
#         [2.7153e-02],
#         [9.6893e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0216, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4983
# w= tensor([[7.0285],
#         [7.0199]], requires_grad=True)
# b= tensor([-10.6078], requires_grad=True)
# hypothesis= tensor([[2.4723e-05],
#         [2.6914e-02],
#         [2.7139e-02],
#         [9.6895e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0216, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4984
# w= tensor([[7.0296],
#         [7.0211]], requires_grad=True)
# b= tensor([-10.6095], requires_grad=True)
# hypothesis= tensor([[2.4681e-05],
#         [2.6899e-02],
#         [2.7124e-02],
#         [9.6897e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0216, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4985
# w= tensor([[7.0307],
#         [7.0222]], requires_grad=True)
# b= tensor([-10.6112], requires_grad=True)
# hypothesis= tensor([[2.4639e-05],
#         [2.6884e-02],
#         [2.7109e-02],
#         [9.6899e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0216, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4986
# w= tensor([[7.0319],
#         [7.0233]], requires_grad=True)
# b= tensor([-10.6129], requires_grad=True)
# hypothesis= tensor([[2.4597e-05],
#         [2.6869e-02],
#         [2.7094e-02],
#         [9.6900e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0216, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4987
# w= tensor([[7.0330],
#         [7.0245]], requires_grad=True)
# b= tensor([-10.6146], requires_grad=True)
# hypothesis= tensor([[2.4555e-05],
#         [2.6855e-02],
#         [2.7079e-02],
#         [9.6902e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0215, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4988
# w= tensor([[7.0341],
#         [7.0256]], requires_grad=True)
# b= tensor([-10.6163], requires_grad=True)
# hypothesis= tensor([[2.4514e-05],
#         [2.6840e-02],
#         [2.7064e-02],
#         [9.6904e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0215, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4989
# w= tensor([[7.0353],
#         [7.0267]], requires_grad=True)
# b= tensor([-10.6180], requires_grad=True)
# hypothesis= tensor([[2.4472e-05],
#         [2.6825e-02],
#         [2.7049e-02],
#         [9.6905e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0215, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4990
# w= tensor([[7.0364],
#         [7.0279]], requires_grad=True)
# b= tensor([-10.6197], requires_grad=True)
# hypothesis= tensor([[2.4431e-05],
#         [2.6810e-02],
#         [2.7034e-02],
#         [9.6907e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0215, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4991
# w= tensor([[7.0375],
#         [7.0290]], requires_grad=True)
# b= tensor([-10.6214], requires_grad=True)
# hypothesis= tensor([[2.4389e-05],
#         [2.6796e-02],
#         [2.7019e-02],
#         [9.6909e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0215, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4992
# w= tensor([[7.0387],
#         [7.0301]], requires_grad=True)
# b= tensor([-10.6230], requires_grad=True)
# hypothesis= tensor([[2.4348e-05],
#         [2.6781e-02],
#         [2.7005e-02],
#         [9.6910e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0215, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4993
# w= tensor([[7.0398],
#         [7.0313]], requires_grad=True)
# b= tensor([-10.6247], requires_grad=True)
# hypothesis= tensor([[2.4306e-05],
#         [2.6766e-02],
#         [2.6990e-02],
#         [9.6912e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0215, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4994
# w= tensor([[7.0409],
#         [7.0324]], requires_grad=True)
# b= tensor([-10.6264], requires_grad=True)
# hypothesis= tensor([[2.4265e-05],
#         [2.6752e-02],
#         [2.6975e-02],
#         [9.6914e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0215, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4995
# w= tensor([[7.0421],
#         [7.0335]], requires_grad=True)
# b= tensor([-10.6281], requires_grad=True)
# hypothesis= tensor([[2.4224e-05],
#         [2.6737e-02],
#         [2.6960e-02],
#         [9.6916e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0214, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4996
# w= tensor([[7.0432],
#         [7.0347]], requires_grad=True)
# b= tensor([-10.6298], requires_grad=True)
# hypothesis= tensor([[2.4183e-05],
#         [2.6722e-02],
#         [2.6945e-02],
#         [9.6917e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0214, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4997
# w= tensor([[7.0443],
#         [7.0358]], requires_grad=True)
# b= tensor([-10.6315], requires_grad=True)
# hypothesis= tensor([[2.4142e-05],
#         [2.6707e-02],
#         [2.6930e-02],
#         [9.6919e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0214, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4998
# w= tensor([[7.0455],
#         [7.0369]], requires_grad=True)
# b= tensor([-10.6332], requires_grad=True)
# hypothesis= tensor([[2.4101e-05],
#         [2.6693e-02],
#         [2.6916e-02],
#         [9.6921e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0214, grad_fn=<MeanBackward0>)
# ====================================================================================================
# i= 4999
# w= tensor([[7.0466],
#         [7.0381]], requires_grad=True)
# b= tensor([-10.6349], requires_grad=True)
# hypothesis= tensor([[2.4060e-05],
#         [2.6678e-02],
#         [2.6901e-02],
#         [9.6922e-01]], grad_fn=<SigmoidBackward0>)
# cost= tensor(0.0214, grad_fn=<MeanBackward0>)
# ====================================================================================================

# %%
#오차가 0으로 수렴하는 w값(초기값은 1, 2였음)
w
# Out:
# tensor([[7.0477],
#         [7.0392]], requires_grad=True)

# %%
#오차가 0으로 수렴하는 b값(초기값은 3이었음)
b
# Out:
# tensor([-10.6366], requires_grad=True)

# %%
torch.sigmoid(torch.matmul(X, w) + b)
# Out:
# tensor([[2.4019e-05],
#         [2.6663e-02],
#         [2.6886e-02],
#         [9.6924e-01]], grad_fn=<SigmoidBackward0>)

# %%
predict = torch.sigmoid(torch.matmul(X, w) + b)
predict
# Out:
# tensor([[2.4019e-05],
#         [2.6663e-02],
#         [2.6886e-02],
#         [9.6924e-01]], grad_fn=<SigmoidBackward0>)

# %%
#predict를 numpy 배열로 변환
predict.detach().numpy()
# Out:
# array([[2.4019317e-05],
#        [2.6663482e-02],
#        [2.6886106e-02],
#        [9.6924007e-01]], dtype=float32)

# %%
#predict에 저장된 값이 0.5 초과이면 1, 아니면 0 리턴
predict01 = np.where(predict.detach().numpy() >= 0.5, 1, 0)
predict01
# Out:
# array([[0],
#        [0],
#        [0],
#        [1]])

# %%
#y를 numpy 배열로 변환
#predict01과 y가 같으면 True, 다르면 False 리턴
predict02 = predict01 == (y.detach().numpy())
predict02
# Out:
# array([[ True],
#        [ True],
#        [ True],
#        [ True]])

# %%
#True는 1, False는 0으로 합을 계산
np.sum(predict02)
# Out:
# 4

# %%
#정확도 계산
np.sum(predict02) / 4
# Out:
# 1.0

# %%
#0, 1의 AND 연산 실행
arr = torch.FloatTensor([
        [0, 1]
    ])

predict = torch.sigmoid(torch.matmul(arr, w) + b)
predict
# Out:
# tensor([[0.0267]], grad_fn=<SigmoidBackward0>)

# %%
#predict에 저장된 값이 0.5 이상이면 1, 아니면 0 리턴
torch.where(predict > 0.5, 1, 0)
# Out:
# tensor([[0]])

# %%
#1, 1의 AND 연산 실행
arr = torch.FloatTensor([
        [1, 1]
    ])

predict = torch.sigmoid(torch.matmul(arr, w) + b)
predict
# Out:
# tensor([[0.9692]], grad_fn=<SigmoidBackward0>)

# %%
#predict에 저장된 값이 0.5 이상이면 1, 아니면 0 리턴
torch.where(predict > 0.5, 1, 0)
# Out:
# tensor([[1]])
